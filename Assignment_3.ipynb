# %% [markdown]
# 1. Why are functions advantageous to have in your programs?
#
# Ans:We can call function multiple times and dont need to write the code again and again.
#
# 2. When does the code in a function run: when it's specified or when it's called?
#
# Ans:The code in a function runs when it is called.
#
# 3. What statement creates a function?
#
# Ans: eg.
#     def my_func():
#         pass
#
# 4. What is the difference between a function and a function call?
#
# Ans:In a function we write the required code and when we call the function the code runs and returns value
#
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# Ans:Variables defined in the main body of the program
#
# 6. What happens to variables in a local scope when the function call returns?
#
# Ans:Yes the value of the local variable can be returned but the local variable cant be used outside the function.
#
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# Ans:return value is basically any value given by a function call.
#     yes we can have a return value in an expression.
#
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Ans:None
#
# 9. How do you make a function variable refer to the global variable?
#
# Ans: We can pass the global variable during function call
#     eg global_var=10
#        def my_func(local_var)
#            pass
#        my_func(global)
#
# 10. What is the data type of None?
#
# Ans:Nonetype
#
# 11. What does the sentence import areallyourpetsnamederic do?
#
# Ans:This statement will help us importing the module areallyourpetsnamederic and then we can use the features and libraries inside that module.
#
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# Ans:spam.bacon()
#
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Ans:We use the try and except statements to handle exceptions. Whenever the code breaks down, an exception is thrown without crashing the program.
#
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# Ans:Try clause helps to handle run time error,if there is any run time error the rest of the codes will run,it wont get blocked.
# When there is run time error in the block of code of try block except clause block executes.
