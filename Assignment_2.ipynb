# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?
#
# Ans:True
#     False
#
# 2. What are the three different types of Boolean operators?
#
# Ans:and or not
#
# 3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).
#
# Ans:A     not
#     True  False
#     False True
#
#     A     B      or     and
#     True  True   True   True
#     True  False  True   False
#     False True   True   False
#     False False  False  False
#
# 4. What are the values of the following expressions?
# (5>4) and (3 == 5)   Ans:False
# not (5>4)  Ans:False
# (5>4) or (3 == 5)  Ans:True
# not ((5>4) or (3 == 5))  Ans:False
# (True and True) and (True == False)  Ans:False
# (not False) or (not True)  Ans:True
#
# 5. What are the six comparison operators?
#
# Ans:> < <= >= == !=
#
# 6. How do you tell the difference between the equal to and assignment operators?Describe a
# condition and when you would use one.
#
# Ans:Equal to operator is used to check if two values are equal or not eg 2==5
#     Assignment operator is used to assign a value to a variable eg a=5
#
#
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam>5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')
#
# Ans:There is indentation error.Print statement is not properly indented.After every if condition print should be typed after a tab.
# There are 3 such blocks in the code containing 3 if conditions followed by print statement.
#
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam.
#
# Ans:
# spam=2
# if spam==1:
#     print('Hello')
# if spam==2:
#     print('Howdy')
# else:
#     print('Greetings!')
#
# 9.If your programme is stuck in an endless loop, what keys you’ll press?
#
# Ans:Ctrl+C
#
#
# 10. How can you tell the difference between break and continue?
#
# Ans:Break will end the running loop and all the statements below break statement within the loop will not be executed.
#     Continue will not allow the statements to be executed below it only when it runs at that time but loop will continue further
#
#
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?
#
# Ans:All three are same
#
#
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.
#
# Ans:for i in range(1,11):
#         print(i)
#
#        i=1
#        while(i<=10):
#            print(i)
#            i+=1
#
#
#
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?
#
# Ans:spam.bacon()
